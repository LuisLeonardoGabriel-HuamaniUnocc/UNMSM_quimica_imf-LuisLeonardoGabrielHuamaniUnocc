# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisLeonardoGabriel-HuamaniUnocc/UNMSM_quimica_practicas_LuisLeonardoGabrielHuamaniUnocc/blob/main/Actividad_%22Estado_gaseoso%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gases (continuación)
#
# Alumno: Luis Leonardo Gabriel Huamani Unocc

# %% [markdown]
# Actividad: Elaborar dataframes y comparar sus medidas de tendencia central para explicar las gráficas (Ref. Teoría cinética molecular de los gases)
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

# Datos
N = 6.022e23 # Constante de Boltzmann (J/K)
m = 0.028    # Masa molar del cloro (g/mol)
k = 1.38e-23 # Masa molar del nitrógeno (g/mol)
T = [100, 300, 700] # Temperatura en Kelvin

temperaturas = []
velocidades_rms = []

for temp in T:
    v_rms = np.sqrt((3 * k * temp) / (m / N))
    temperaturas.append(temp)
    velocidades_rms.append(v_rms)

df = pd.DataFrame({
    'Temperatura (K)': temperaturas,
    'Velocidad cuadrática media (m/s)': velocidades_rms
})

table = tabulate(df, headers='keys', tablefmt='grid')

print(table)

media = df['Velocidad cuadrática media (m/s)'].mean()
mediana = df['Velocidad cuadrática media (m/s)'].median()

print(f'\nMedia de la velocidad cuadrática media: {media} m/s')
print(f'Mediana de la velocidad cuadrática media: {mediana} m/s')
# Out:
# +----+-------------------+------------------------------------+
# |    |   Temperatura (K) |   Velocidad cuadrática media (m/s) |
# +====+===================+====================================+
# |  0 |               100 |                            298.395 |
# +----+-------------------+------------------------------------+
# |  1 |               300 |                            516.835 |
# +----+-------------------+------------------------------------+
# |  2 |               700 |                            789.479 |
# +----+-------------------+------------------------------------+
#
# Media de la velocidad cuadrática media: 534.9030739234113 m/s
# Mediana de la velocidad cuadrática media: 516.835287384399 m/s

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

# Datos
k = 1.38e-23  # Constante de Boltzmann (J/K)
m_cl2 = 70.906  # Masa molar del cloro (g/mol)
m_n2 = 28.0134  # Masa molar del nitrógeno (g/mol)
m_he = 4.002602  # Masa molar del helio (g/mol)

# La temperatura es 300k

v_rms_cl2 = np.sqrt(3 * k * 300 / (m_cl2 / 6.022e23))
v_rms_n2 = np.sqrt(3 * k * 300 / (m_n2 / 6.022e23))
v_rms_he = np.sqrt(3 * k * 300 / (m_he / 6.022e23))

df = pd.DataFrame({
    'Molécula': ['Cl2', 'N2', 'He'],
    'Velocidad cuadrática media (m/s)': [v_rms_cl2, v_rms_n2, v_rms_he]
})

table = tabulate(df, headers='keys', tablefmt='grid')

print(table)

media = df['Velocidad cuadrática media (m/s)'].mean()
mediana = df['Velocidad cuadrática media (m/s)'].median()

print(f'\nMedia: {media} m/s')
print(f'Mediana: {mediana} m/s')
# Out:
# +----+------------+------------------------------------+
# |    | Molécula   |   Velocidad cuadrática media (m/s) |
# +====+============+====================================+
# |  0 | Cl2        |                            10.2705 |
# +----+------------+------------------------------------+
# |  1 | N2         |                            16.3399 |
# +----+------------+------------------------------------+
# |  2 | He         |                            43.2275 |
# +----+------------+------------------------------------+
#
# Media: 23.279265796617988 m/s
# Mediana: 16.339857406052197 m/s
